# %%
# !pip install jdc
import jdc

# %%
from collections import namedtuple

path = namedtuple('path', 'from_ to_')


class Environment:
    def __init__(self, states=[], paths={}):
        self.states = states # All the possible states in the environment.
        self.paths = paths # A dictionary that maps a path object to its associated reward.

    def add_state(self, name='S'): # Allows the addition of a new state to the environment.
        self.states[name] = name

    def add_path(self, path, reward=1): # Allows the addition of a new path to the environment.
        """
        Parameters:
        path: a path
        reward: reward for taking the given path
        """
        if path not in self.paths.keys():  # no duplicates
            self.paths[path] = reward
        if path.from_ not in self.states:
            self.states.append(path.from_)
        if path.to_ not in self.states:
            self.states.append(path.to_)

    def reward(self, action): # Returns the reward associated with a particular path, if it exists.
        if action in self.paths:
            return self.paths[action]
        else:
            return 0 # Returns 0 if path does not exist.

    def __str__(self): #  Returns a string representation of the environment.
        e = 'States:\n\t'
        e += ' '.join([str(s) for s in self.states])
        e += '\nPaths:'
        e += ' '.join(['\n ' + str(p) for p in self.paths])
        return

# %%
import random
from collections import namedtuple

path = namedtuple('path', 'from_ to_')


class Agent:
    def __init__(self,
                 env,
                 goal_state,
                 explore=0.9,
                 discount_rate=0.9,
                 learning_rate=0.1,
                 iterations=1000,
                 seed=2):
        self.gamma = discount_rate
        self.alpha = learning_rate
        self.env = env
        self.Q = {} # dictionary to hold Q-values
        self.len_path_to_goal = 0
        self.goal_state = goal_state
        self.explore_or_exploit = explore # exploration probability
        self.iterations = iterations
        random.seed(seed)

    def update_Q(self, action, reward):
        future_paths = [p for p in self.Q.keys if p._from == action[1]]
        # max_value_future_path =
        self.Q[action] = reward + self.gamma * self.Q[action] - self.Q[action]

    def learn(self):
        for i in range(self.iterations):
            from_ = random.choice(range(len(self.env.states))) # randomly choose starting state
            # Explore or exploit
            x = random.random()
            print(x)
            if x > self.explore_or_exploit: # Explore
                to_ = random.choice(range(len(self.env.states))) # randomly choose destination state
                print('Exploring path ', path(from_, to_))
            else: # exploit
                max_quality = 0
                to_ = from_
                for fs, ts in self.Q.keys(): # iterate over all possible actions from the current state
                    if fs == from_ and (max_quality < self.Q[(fs,ts)]): # find the action with the highest Q-value
                        max_quality = self.Q[path(fs,ts)]
                        to_ = ts
                print('Exploiting path ', path(from_, to_))
            action = path(from_, to_) # create an action based on the chosen states
            # get reward
            R = self.env.reward(action)
            # update quality of action
            #
            if action not in self.Q.keys():
                self.Q[action] = 0 
            # quality of a state is equal to the action
            # that can be taken in this state
            current_state_quality = self.Q[action] # current Q-value of the action
            # future_paths is the list of possible future actions from the next state
            future_paths = []  # [p for p  in self.Q.keys() if p.from_ == action.to_]
            for p in self.Q.keys():
                if p.from_ == action.to_:
                    future_paths.append(p)
            if len(future_paths) == 0:
                future_state_quality = 0
            else:
                future_state_quality = max(
                    [self.Q[p] for p in future_paths])  # max achievable quality of possible actions in future state
            # max_value_future_path =
            td = R + (self.gamma * future_state_quality) - current_state_quality
            self.Q[action] = self.Q[action] + (self.alpha * td) # update Q-value of the action
        print(self.Q)

    def go(self, from_): 
        max_q_action = 0
        max_q_state = None
        for to_ in self.env.states: # Loop through all possible states to find the state with the maximum Q-value.
            if self.Q[path(from_, to_)] > max_q_action: # Check if the Q-value for the current action is greater than the current maximum Q-value.
                max_q_action = self.Q[path(from_, to_)] # Update the maximum Q-value to the Q-value of the current action.
                max_q_state = to_
        print(from_, max_q_state)
        if max_q_state == self.goal_state: # Check if the maximum Q-value state is the goal state.
            return  # reached
        # quit recursion if path is > 20
        self.len_path_to_goal += 1
        if self.len_path_to_goal > 20:
            return
        self.go(from_=max_q_state) # Recursively call the go function with the state corresponding to the maximum Q-value.

    def tester(self): # Print a dictionary which shows the Q-values for each action from each state.
        self.matrix = []
        for from_ in self.env.states:
            v = []
            for to_ in self.env.states:
                v.append(self.Q[path(from_, to_)])
            self.matrix.append({from_: v})
        for x in self.matrix:
            print(x)

# %%
e = Environment()
e.add_path(path(0, 1))
e.add_path(path(1, 2))
e.add_path(path(2, 3))
e.add_path(path(3, 4))
e.add_path(path(4, 0))
e.add_path(path(4, 5))
e.add_path(path(5, 0))
e.add_path(path(5, 1))
e.add_path(path(5, 2))
e.add_path(path(5, 3))
e.add_path(path(5, 4))
e.add_path(path(5, 5), 1.1)

# %%
# Run the algorithm
a = Agent(env=e, goal_state=5, explore=0.1, iterations=1000) # Creates an agent
"""
Parameters:
env: The environment the agent will navigate.
goal_state: The goal state the agent is trying to reach.
explore: Exploration rate.
iterations: The number of iterations the agent will use to learn.
"""
a.learn() # Trains the agent using the Q-learning algorithm for the specified number of iterations.
a.tester() # Prints a dictionary which shows the Q-values for each action from each state.
for state in e.states: # Iterates over each state in the environment.
    print('from ', state) # Prints the 'from'/starting state
    a.path_length = 0 
    # a.go(state) Selects the highest Q-value action until the goal is reached or a maximum path length is exceeded.
    a.go(state)
# Out:
# 0.09158478740507359
# Exploiting path  path(from_=0, to_=0)
# 0.8354988781294496
# Exploring path  path(from_=2, to_=5)
# 0.8538343854854736
# Exploring path  path(from_=5, to_=2)
# 0.2122188106686006
# Exploring path  path(from_=4, to_=0)
# 0.6812461849926625
# Exploring path  path(from_=4, to_=3)
# 0.39353182020537136
# Exploring path  path(from_=5, to_=5)
# 0.9493954730932436
# Exploring path  path(from_=4, to_=4)
# 0.5020672922450359
# Exploring path  path(from_=3, to_=0)
# 0.36401442784736937
# Exploring path  path(from_=0, to_=2)
# 0.42361096957169064
# Exploring path  path(from_=3, to_=4)
# 0.5605103610264989
# Exploring path  path(from_=1, to_=1)
# 0.023858079140782196
# Exploiting path  path(from_=1, to_=1)
# 0.1735887537650569
# Exploring path  path(from_=2, to_=4)
# 0.3596914037964013
# Exploring path  path(from_=4, to_=4)
# 0.5598903162914775
# Exploring path  path(from_=5, to_=3)
# 0.7344016918939777
# Exploring path  path(from_=3, to_=2)
# 0.3537869778416035
# Exploring path  path(from_=4, to_=3)
# 0.9549331199676101
# Exploring path  path(from_=1, to_=3)
# 0.7385902215645216
# Exploring path  path(from_=5, to_=5)
# 0.2499017677457177
# Exploring path  path(from_=4, to_=2)
# 0.5008410626306549
# Exploring path  path(from_=3, to_=2)
# 0.8828509185812531
# Exploring path  path(from_=5, to_=3)
# 0.5677050704202443
# Exploring path  path(from_=2, to_=4)
# 0.45655111586010866
# Exploring path  path(from_=5, to_=5)
# 0.9405965158691051
# Exploring path  path(from_=1, to_=5)
# 0.8766961761410571
# Exploring path  path(from_=1, to_=4)
# 0.7729840570045846
# Exploring path  path(from_=2, to_=3)
# 0.3032967445057757
# Exploring path  path(from_=2, to_=5)
# 0.5621887036990206
# Exploring path  path(from_=4, to_=4)
# 0.6158082156475239
# Exploring path  path(from_=5, to_=3)
# 0.7309298754320924
# Exploring path  path(from_=2, to_=3)
# 0.36659824799116214
# Exploring path  path(from_=4, to_=5)
# 0.8820695435656262
# Exploring path  path(from_=4, to_=2)
# 0.00842182269434344
# Exploiting path  path(from_=5, to_=5)
# 0.9970685969649458
# Exploring path  path(from_=1, to_=0)
# 0.5744149584539974
# Exploring path  path(from_=0, to_=0)
# 0.5917003171638885
# Exploring path  path(from_=2, to_=5)
# 0.7543697843131622
# Exploring path  path(from_=0, to_=1)
# 0.2448319779690169
# Exploring path  path(from_=2, to_=1)
# 0.42291764838969603
# Exploring path  path(from_=0, to_=5)
# 0.05679641188947038
# Exploiting path  path(from_=0, to_=1)
# 0.17188099212573238
# Exploring path  path(from_=2, to_=5)
# 0.08290317740457553
# Exploiting path  path(from_=0, to_=1)
# 0.025344714826901038
# Exploiting path  path(from_=0, to_=1)
# 0.9186300338890021
# Exploring path  path(from_=5, to_=2)
# 0.12778713415082077
# Exploring path  path(from_=2, to_=1)
# 0.1837388092509762
# Exploring path  path(from_=5, to_=5)
# 0.38556588135256054
# Exploring path  path(from_=0, to_=0)
# 0.15142010875655154
# Exploring path  path(from_=1, to_=0)
# 0.34420100553679467
# Exploring path  path(from_=0, to_=4)
# 0.7424596231257796
# Exploring path  path(from_=5, to_=0)
# 0.33721377319664525
# Exploring path  path(from_=2, to_=0)
# 0.448653262492294
# Exploring path  path(from_=2, to_=4)
# 0.04577246235326049
# Exploiting path  path(from_=5, to_=5)
# 0.7556621536750643
# Exploring path  path(from_=2, to_=4)
# 0.1534555589614771
# Exploring path  path(from_=5, to_=1)
# 0.6608284986570139
# Exploring path  path(from_=0, to_=2)
# 0.02420382535324883
# Exploiting path  path(from_=0, to_=1)
# 0.518286105878321
# Exploring path  path(from_=1, to_=3)
# 0.5148026967641771
# Exploring path  path(from_=3, to_=1)
# 0.2590964232522055
# Exploring path  path(from_=2, to_=4)
# 0.6533146278413624
# Exploring path  path(from_=3, to_=5)
# 0.9589999552113516
# Exploring path  path(from_=4, to_=5)
# 0.2529669183012563
# Exploring path  path(from_=0, to_=1)
# 0.1707107655396457
# Exploring path  path(from_=1, to_=3)
# 0.23165507248237116
# Exploring path  path(from_=5, to_=5)
# 0.9945252332595031
# Exploring path  path(from_=0, to_=1)
# 0.4446974551196967
# Exploring path  path(from_=5, to_=2)
# 0.591237345547998
# Exploring path  path(from_=0, to_=4)
# 0.7094983038293496
# Exploring path  path(from_=4, to_=2)
# 0.42301692276252156
# Exploring path  path(from_=5, to_=4)
# 0.15111544754728234
# Exploring path  path(from_=0, to_=3)
# 0.16023574852328715
# Exploring path  path(from_=3, to_=4)
# 0.08782135129619772
# Exploiting path  path(from_=5, to_=5)
# 0.09977308675499097
# Exploiting path  path(from_=0, to_=1)
# 0.750585192676823
# Exploring path  path(from_=1, to_=0)
# 0.024440106158974406
# Exploiting path  path(from_=1, to_=0)
# 0.46440311114384025
# Exploring path  path(from_=5, to_=2)
# 0.6417587576806747
# Exploring path  path(from_=4, to_=1)
# 0.9065626767316824
# Exploring path  path(from_=5, to_=1)
# 0.8060797708759745
# Exploring path  path(from_=5, to_=3)
# 0.021322627224596546
# Exploiting path  path(from_=4, to_=5)
# 0.051234743605830024
# Exploiting path  path(from_=4, to_=5)
# 0.9288806656380335
# Exploring path  path(from_=3, to_=4)
# 0.920616329415044
# Exploring path  path(from_=1, to_=5)
# 0.3661839665433979
# Exploring path  path(from_=3, to_=4)
# 0.6105103371030303
# Exploring path  path(from_=0, to_=2)
# 0.9835210735533187
# Exploring path  path(from_=5, to_=2)
# 0.019055104809604595
# Exploiting path  path(from_=2, to_=3)
# 0.4122542969969054
# Exploring path  path(from_=5, to_=0)
# 0.1983913543865955
# Exploring path  path(from_=2, to_=5)
# 0.8120604042069871
# Exploring path  path(from_=0, to_=0)
# 0.6372948101599734
# Exploring path  path(from_=3, to_=3)
# 0.8895419060345371
# Exploring path  path(from_=1, to_=4)
# 0.005328247579629353
# Exploiting path  path(from_=0, to_=1)
# 0.37290210504696797
# Exploring path  path(from_=0, to_=5)
# 0.2191652786358007
# Exploring path  path(from_=0, to_=3)
# 0.11576836982036187
# Exploring path  path(from_=1, to_=2)
# 0.7159246762337117
# Exploring path  path(from_=3, to_=1)
# 0.3950425601578629
# Exploring path  path(from_=2, to_=0)
# 0.12177009972153996
# Exploring path  path(from_=2, to_=0)
# 0.8500708739048479
# Exploring path  path(from_=4, to_=5)
# 0.9596685633958122
# Exploring path  path(from_=3, to_=5)
# 0.024668772654101057
# Exploiting path  path(from_=0, to_=1)
# 0.47037448568054985
# Exploring path  path(from_=5, to_=0)
# 0.7058035544898325
# Exploring path  path(from_=5, to_=2)
# 0.9595995653944888
# Exploring path  path(from_=2, to_=1)
# 0.26894249382765256
# Exploring path  path(from_=2, to_=4)
# 0.7195468243561449
# Exploring path  path(from_=3, to_=5)
# 0.9320538602182384
# Exploring path  path(from_=3, to_=5)
# 0.3946718218298805
# Exploring path  path(from_=2, to_=1)
# 0.5965556670681039
# Exploring path  path(from_=3, to_=4)
# 0.6956185302074269
# Exploring path  path(from_=3, to_=5)
# 0.5859005803451007
# Exploring path  path(from_=0, to_=4)
# 0.07115986463470181
# Exploiting path  path(from_=0, to_=1)
# 0.9977480213736307
# Exploring path  path(from_=1, to_=1)
# 0.8982047965142085
# Exploring path  path(from_=3, to_=0)
# 0.9886370287076425
# Exploring path  path(from_=5, to_=5)
# 0.12851500491734336
# Exploring path  path(from_=0, to_=2)
# 0.2316996433466908
# Exploring path  path(from_=3, to_=5)
# 0.32941465406750015
# Exploring path  path(from_=5, to_=1)
# 0.2869883262520303
# Exploring path  path(from_=4, to_=1)
# 0.9866863038386309
# Exploring path  path(from_=4, to_=3)
# 0.32884363469855005
# Exploring path  path(from_=0, to_=1)
# 0.5141659547184446
# Exploring path  path(from_=5, to_=1)
# 0.4609409641279719
# Exploring path  path(from_=1, to_=5)
# 0.40416338946274066
# Exploring path  path(from_=1, to_=2)
# 0.728924469238259
# Exploring path  path(from_=4, to_=3)
# 0.7188684868021674
# Exploring path  path(from_=3, to_=4)
# 0.8818175177034232
# Exploring path  path(from_=3, to_=1)
# 0.510171503227743
# Exploring path  path(from_=3, to_=3)
# 0.40491467903346945
# Exploring path  path(from_=2, to_=5)
# 0.9366699189852588
# Exploring path  path(from_=5, to_=5)
# 0.47249917954286
# Exploring path  path(from_=5, to_=4)
# 0.7132595684052463
# Exploring path  path(from_=2, to_=5)
# 0.7616088749444486
# Exploring path  path(from_=0, to_=5)
# 0.5328545020613746
# Exploring path  path(from_=1, to_=1)
# 0.8162903015834978
# Exploring path  path(from_=3, to_=3)
# 0.9149698839456274
# Exploring path  path(from_=5, to_=2)
# 0.5235732846824562
# Exploring path  path(from_=3, to_=3)
# 0.1773688108926259
# Exploring path  path(from_=5, to_=0)
# 0.40292168366335
# Exploring path  path(from_=0, to_=1)
# 0.5692675158861573
# Exploring path  path(from_=5, to_=3)
# 0.884679727052069
# Exploring path  path(from_=1, to_=0)
# 0.8156212162801871
# Exploring path  path(from_=3, to_=1)
# 0.7442456925018666
# Exploring path  path(from_=2, to_=4)
# 0.1914944238201054
# Exploring path  path(from_=4, to_=4)
# 0.00848430106284992
# Exploiting path  path(from_=1, to_=2)
# 0.43439798416239184
# Exploring path  path(from_=5, to_=2)
# 0.5660946233091266
# Exploring path  path(from_=4, to_=3)
# 0.20499749461103856
# Exploring path  path(from_=5, to_=0)
# 0.003037288082221923
# Exploiting path  path(from_=2, to_=3)
# 0.5331662136107049
# Exploring path  path(from_=3, to_=5)
# 0.06544469114146811
# Exploiting path  path(from_=5, to_=5)
# 0.4850004533300901
# Exploring path  path(from_=4, to_=5)
# 0.4593056758265589
# Exploring path  path(from_=2, to_=4)
# 0.027527816497436852
# Exploiting path  path(from_=3, to_=4)
# 0.6134837922003845
# Exploring path  path(from_=0, to_=2)
# 0.7596241813172081
# Exploring path  path(from_=1, to_=3)
# 0.6749931843961182
# Exploring path  path(from_=2, to_=5)
# 0.05407944442756574
# Exploiting path  path(from_=1, to_=2)
# 0.3816634192488769
# Exploring path  path(from_=3, to_=3)
# 0.29481887188440636
# Exploring path  path(from_=5, to_=0)
# 0.5574216728463172
# Exploring path  path(from_=2, to_=0)
# 0.03401724649965321
# Exploiting path  path(from_=2, to_=3)
# 0.5643062624543941
# Exploring path  path(from_=3, to_=1)
# 0.3084304444363558
# Exploring path  path(from_=5, to_=5)
# 0.48378653593083976
# Exploring path  path(from_=1, to_=4)
# 0.9147031255268172
# Exploring path  path(from_=5, to_=0)
# 0.8243704312524108
# Exploring path  path(from_=2, to_=2)
# 0.6463082726925741
# Exploring path  path(from_=2, to_=2)
# 0.642770382709552
# Exploring path  path(from_=5, to_=4)
# 0.5084594535329521
# Exploring path  path(from_=0, to_=1)
# 0.5961922893707899
# Exploring path  path(from_=3, to_=1)
# 0.6288401714648099
# Exploring path  path(from_=4, to_=2)
# 0.23291382156000595
# Exploring path  path(from_=0, to_=3)
# 0.23210957290703327
# Exploring path  path(from_=4, to_=2)
# 0.9577546426051324
# Exploring path  path(from_=0, to_=0)
# 0.8186163737430314
# Exploring path  path(from_=5, to_=3)
# 0.2137166210889183
# Exploring path  path(from_=2, to_=2)
# 0.33471350712612413
# Exploring path  path(from_=0, to_=2)
# 0.4975836607963514
# Exploring path  path(from_=1, to_=2)
# 0.8945732052166709
# Exploring path  path(from_=3, to_=5)
# 0.9907267290325479
# Exploring path  path(from_=3, to_=1)
# 0.32622664540249724
# Exploring path  path(from_=2, to_=0)
# 0.46889018408616034
# Exploring path  path(from_=1, to_=5)
# 0.18533441689683428
# Exploring path  path(from_=2, to_=1)
# 0.23317208341237605
# Exploring path  path(from_=1, to_=4)
# 0.3780063644070931
# Exploring path  path(from_=5, to_=5)
# 0.28074437289373055
# Exploring path  path(from_=2, to_=5)
# 0.5026063217286582
# Exploring path  path(from_=4, to_=5)
# 0.9487821111119297
# Exploring path  path(from_=5, to_=5)
# 0.7510070481436011
# Exploring path  path(from_=3, to_=5)
# 0.7535343167895415
# Exploring path  path(from_=5, to_=5)
# 0.5319394292122587
# Exploring path  path(from_=2, to_=5)
# 0.07266908412750261
# Exploiting path  path(from_=5, to_=5)
# 0.39517778518795865
# Exploring path  path(from_=2, to_=1)
# 0.9577122993866662
# Exploring path  path(from_=2, to_=2)
# 0.4766340113259664
# Exploring path  path(from_=3, to_=1)
# 0.960669497989223
# Exploring path  path(from_=2, to_=1)
# 0.10426936559960243
# Exploring path  path(from_=0, to_=1)
# 0.07703699855241408
# Exploiting path  path(from_=2, to_=3)
# 0.7615609366577561
# Exploring path  path(from_=5, to_=3)
# 0.5426864051848086
# Exploring path  path(from_=0, to_=1)
# 0.3899111117508093
# Exploring path  path(from_=4, to_=2)
# 0.6378060124866672
# Exploring path  path(from_=3, to_=1)
# 0.3163505211631158
# Exploring path  path(from_=2, to_=3)
# 0.9707160826191302
# Exploring path  path(from_=0, to_=1)
# 0.25098002807324715
# Exploring path  path(from_=2, to_=3)
# 0.25017622924701477
# Exploring path  path(from_=2, to_=2)
# 0.2464813940773698
# Exploring path  path(from_=1, to_=1)
# 0.6106047559295025
# Exploring path  path(from_=5, to_=2)
# 0.6479743403778714
# Exploring path  path(from_=2, to_=4)
# 0.8622969101670562
# Exploring path  path(from_=0, to_=1)
# 0.42977737965883234
# Exploring path  path(from_=0, to_=2)
# 0.3209781089647865
# Exploring path  path(from_=1, to_=4)
# 0.3380417350545395
# Exploring path  path(from_=0, to_=5)
# 0.9573856323553145
# Exploring path  path(from_=4, to_=1)
# 0.3923027870548892
# Exploring path  path(from_=0, to_=3)
# 0.6194857051325665
# Exploring path  path(from_=3, to_=2)
# 0.837638978820522
# Exploring path  path(from_=4, to_=4)
# 0.5880005919220117
# Exploring path  path(from_=0, to_=4)
# 0.9849336035230016
# Exploring path  path(from_=5, to_=3)
# 0.4545762029990773
# Exploring path  path(from_=5, to_=3)
# 0.5247667912590958
# Exploring path  path(from_=3, to_=0)
# 0.4513313099388603
# Exploring path  path(from_=0, to_=4)
# 0.11845260811883518
# Exploring path  path(from_=1, to_=5)
# 0.9150902790955766
# Exploring path  path(from_=4, to_=0)
# 0.3058103431589373
# Exploring path  path(from_=3, to_=5)
# 0.25294648934870934
# Exploring path  path(from_=0, to_=5)
# 0.22058953473819964
# Exploring path  path(from_=2, to_=0)
# 0.42730488382104304
# Exploring path  path(from_=1, to_=0)
# 0.9715043441930749
# Exploring path  path(from_=2, to_=5)
# 0.04976662887799366
# Exploiting path  path(from_=3, to_=4)
# 0.24152652967438815
# Exploring path  path(from_=3, to_=3)
# 0.5587665813444036
# Exploring path  path(from_=1, to_=1)
# 0.5021589066248724
# Exploring path  path(from_=5, to_=0)
# 0.19960704107698468
# Exploring path  path(from_=0, to_=0)
# 0.3375866761941143
# Exploring path  path(from_=4, to_=4)
# 0.13996620007992855
# Exploring path  path(from_=1, to_=3)
# 0.13176352188090934
# Exploring path  path(from_=0, to_=0)
# 0.10823545207358609
# Exploring path  path(from_=1, to_=1)
# 0.6160362974942997
# Exploring path  path(from_=0, to_=5)
# 0.33674101250386146
# Exploring path  path(from_=3, to_=5)
# 0.9041848326844553
# Exploring path  path(from_=3, to_=5)
# 0.5070876909863035
# Exploring path  path(from_=4, to_=5)
# 0.5109713383424687
# Exploring path  path(from_=1, to_=1)
# 0.957174511330683
# Exploring path  path(from_=5, to_=1)
# 0.20189228130425363
# Exploring path  path(from_=3, to_=2)
# 0.14372316321529233
# Exploring path  path(from_=3, to_=1)
# 0.3136901020835331
# Exploring path  path(from_=3, to_=2)
# 0.562462755292335
# Exploring path  path(from_=0, to_=3)
# 0.28445924466388006
# Exploring path  path(from_=2, to_=3)
# 0.2291029797544577
# Exploring path  path(from_=2, to_=5)
# 0.6990559663402486
# Exploring path  path(from_=1, to_=5)
# 0.03061509580877053
# Exploiting path  path(from_=0, to_=1)
# 0.7517651632578184
# Exploring path  path(from_=4, to_=1)
# 0.3914731411619701
# Exploring path  path(from_=1, to_=0)
# 0.13809830416316127
# Exploring path  path(from_=5, to_=0)
# 0.2625107668537171
# Exploring path  path(from_=5, to_=5)
# 0.5396796841009821
# Exploring path  path(from_=3, to_=5)
# 0.8354757215415436
# Exploring path  path(from_=1, to_=4)
# 0.0381693295317429
# Exploiting path  path(from_=2, to_=3)
# 0.9971424721803046
# Exploring path  path(from_=1, to_=1)
# 0.6938701610586153
# Exploring path  path(from_=5, to_=1)
# 0.9779762155321453
# Exploring path  path(from_=0, to_=3)
# 0.29179488094821937
# Exploring path  path(from_=5, to_=1)
# 0.8241168508255798
# Exploring path  path(from_=1, to_=5)
# 0.849799699354604
# Exploring path  path(from_=2, to_=4)
# 0.06752907792245388
# Exploiting path  path(from_=4, to_=5)
# 0.6677674779330223
# Exploring path  path(from_=3, to_=0)
# 0.297417727554254
# Exploring path  path(from_=3, to_=0)
# 0.7023150975575135
# Exploring path  path(from_=5, to_=2)
# 0.21439408077736977
# Exploring path  path(from_=0, to_=2)
# 0.5380118692509301
# Exploring path  path(from_=2, to_=3)
# 0.5254566799678791
# Exploring path  path(from_=4, to_=1)
# 0.7721813926752829
# Exploring path  path(from_=3, to_=5)
# 0.7862366950099818
# Exploring path  path(from_=1, to_=3)
# 0.9704915757913131
# Exploring path  path(from_=3, to_=3)
# 0.6126860548151948
# Exploring path  path(from_=3, to_=4)
# 0.5808160265990017
# Exploring path  path(from_=1, to_=3)
# 0.755301061789308
# Exploring path  path(from_=1, to_=4)
# 0.30946163140808325
# Exploring path  path(from_=2, to_=1)
# 0.6050733300021625
# Exploring path  path(from_=2, to_=3)
# 0.7685396419144326
# Exploring path  path(from_=1, to_=5)
# 0.5768951988581144
# Exploring path  path(from_=5, to_=1)
# 0.9340937682078834
# Exploring path  path(from_=5, to_=1)
# 0.8368627564852223
# Exploring path  path(from_=4, to_=2)
# 0.012625610746104243
# Exploiting path  path(from_=0, to_=1)
# 0.19790653132846492
# Exploring path  path(from_=0, to_=2)
# 0.31893603901088374
# Exploring path  path(from_=0, to_=2)
# 0.6645470361623147
# Exploring path  path(from_=5, to_=3)
# 0.41935193889319666
# Exploring path  path(from_=0, to_=5)
# 0.28262601479736427
# Exploring path  path(from_=0, to_=4)
# 0.21223737411597088
# Exploring path  path(from_=1, to_=1)
# 0.7711864216305433
# Exploring path  path(from_=4, to_=5)
# 0.6331635310366105
# Exploring path  path(from_=0, to_=3)
# 0.6451082831789662
# Exploring path  path(from_=2, to_=3)
# 0.8007872759436383
# Exploring path  path(from_=3, to_=1)
# 0.5649094901927918
# Exploring path  path(from_=1, to_=1)
# 0.6182928063246781
# Exploring path  path(from_=1, to_=2)
# 0.6157697864042746
# Exploring path  path(from_=4, to_=3)
# 0.40676056768507385
# Exploring path  path(from_=4, to_=5)
# 0.5611636047206422
# Exploring path  path(from_=1, to_=2)
# 0.24941724641886442
# Exploring path  path(from_=5, to_=4)
# 0.3912383528388118
# Exploring path  path(from_=5, to_=3)
# 0.9704453085048914
# Exploring path  path(from_=0, to_=3)
# 0.4747633409578357
# Exploring path  path(from_=3, to_=3)
# 0.21511261344409716
# Exploring path  path(from_=2, to_=1)
# 0.53260290268721
# Exploring path  path(from_=0, to_=0)
# 0.9456404860580907
# Exploring path  path(from_=4, to_=5)
# 0.0538240178468985
# Exploiting path  path(from_=0, to_=1)
# 0.4306062713379225
# Exploring path  path(from_=5, to_=1)
# 0.272774749256507
# Exploring path  path(from_=4, to_=2)
# 0.3612180539960067
# Exploring path  path(from_=4, to_=3)
# 0.07029001939909241
# Exploiting path  path(from_=4, to_=5)
# 0.7345369510542991
# Exploring path  path(from_=3, to_=1)
# 0.02476395688483124
# Exploiting path  path(from_=2, to_=3)
# 0.041749172876229146
# Exploiting path  path(from_=3, to_=4)
# 0.14178118263552142
# Exploring path  path(from_=5, to_=2)
# 0.5376941490812788
# Exploring path  path(from_=1, to_=4)
# 0.6463632531114818
# Exploring path  path(from_=1, to_=0)
# 0.5579551424151222
# Exploring path  path(from_=5, to_=0)
# 0.670020484450388
# Exploring path  path(from_=5, to_=3)
# 0.14016408498504118
# Exploring path  path(from_=5, to_=2)
# 0.6605258156978157
# Exploring path  path(from_=4, to_=3)
# 0.944403995247895
# Exploring path  path(from_=0, to_=2)
# 0.686331658978618
# Exploring path  path(from_=2, to_=0)
# 0.3595582850802208
# Exploring path  path(from_=4, to_=4)
# 0.3634126171098261
# Exploring path  path(from_=2, to_=5)
# 0.8049024453622954
# Exploring path  path(from_=2, to_=2)
# 0.6002114114705801
# Exploring path  path(from_=4, to_=1)
# 0.04431206986600389
# Exploiting path  path(from_=0, to_=1)
# 0.8377837511392343
# Exploring path  path(from_=3, to_=0)
# 0.6724631411952251
# Exploring path  path(from_=2, to_=4)
# 0.05069604413327944
# Exploiting path  path(from_=5, to_=5)
# 0.07672834910750082
# Exploiting path  path(from_=5, to_=5)
# 0.5066210300446902
# Exploring path  path(from_=4, to_=3)
# 0.41941106498143466
# Exploring path  path(from_=3, to_=1)
# 0.6137128326668178
# Exploring path  path(from_=1, to_=0)
# 0.7598941174631587
# Exploring path  path(from_=4, to_=5)
# 0.673161269585832
# Exploring path  path(from_=2, to_=2)
# 0.9043505629117216
# Exploring path  path(from_=0, to_=0)
# 0.5659211932724164
# Exploring path  path(from_=1, to_=1)
# 0.06330695680660547
# Exploiting path  path(from_=3, to_=4)
# 0.11085996724186775
# Exploring path  path(from_=2, to_=4)
# 0.24263823206242952
# Exploring path  path(from_=0, to_=4)
# 0.10294530545383851
# Exploring path  path(from_=1, to_=5)
# 0.07999380305558346
# Exploiting path  path(from_=3, to_=4)
# 0.5820045296225238
# Exploring path  path(from_=2, to_=1)
# 0.5255731680798436
# Exploring path  path(from_=0, to_=4)
# 0.4270754897208028
# Exploring path  path(from_=3, to_=1)
# 0.4268904561521276
# Exploring path  path(from_=1, to_=3)
# 0.3728036735415179
# Exploring path  path(from_=5, to_=4)
# 0.5164054991159571
# Exploring path  path(from_=1, to_=3)
# 0.5992436181828189
# Exploring path  path(from_=3, to_=5)
# 0.1623927317231908
# Exploring path  path(from_=3, to_=4)
# 0.8527091618698439
# Exploring path  path(from_=1, to_=1)
# 0.251312857159803
# Exploring path  path(from_=0, to_=1)
# 0.6378377632214752
# Exploring path  path(from_=1, to_=4)
# 0.2504103778366278
# Exploring path  path(from_=5, to_=3)
# 0.4644265114376729
# Exploring path  path(from_=3, to_=3)
# 0.2694151682766086
# Exploring path  path(from_=3, to_=1)
# 0.7506735893522437
# Exploring path  path(from_=2, to_=0)
# 0.6215408506672343
# Exploring path  path(from_=3, to_=0)
# 0.30224727042962607
# Exploring path  path(from_=3, to_=0)
# 0.47727427310436565
# Exploring path  path(from_=4, to_=2)
# 0.2705635372335291
# Exploring path  path(from_=5, to_=3)
# 0.45703109625757243
# Exploring path  path(from_=5, to_=4)
# 0.4617241316095889
# Exploring path  path(from_=4, to_=5)
# 0.5560949433415722
# Exploring path  path(from_=1, to_=4)
# 0.46087192213608286
# Exploring path  path(from_=1, to_=2)
# 0.10973660279346042
# Exploring path  path(from_=3, to_=5)
# 0.7470187468095937
# Exploring path  path(from_=1, to_=5)
# 0.9588396876069631
# Exploring path  path(from_=5, to_=0)
# 0.597999330322902
# Exploring path  path(from_=3, to_=4)
# 0.45462035454924343
# Exploring path  path(from_=4, to_=5)
# 0.4525465191624486
# Exploring path  path(from_=3, to_=5)
# 0.7391209927405722
# Exploring path  path(from_=5, to_=4)
# 0.1655711840607641
# Exploring path  path(from_=2, to_=1)
# 0.8963367614838659
# Exploring path  path(from_=5, to_=1)
# 0.4511510468933474
# Exploring path  path(from_=3, to_=5)
# 0.8080668983805169
# Exploring path  path(from_=5, to_=3)
# 0.911710041110168
# Exploring path  path(from_=2, to_=4)
# 0.2991907793793349
# Exploring path  path(from_=3, to_=5)
# 0.6703047477717768
# Exploring path  path(from_=2, to_=5)
# 0.40083144301413376
# Exploring path  path(from_=0, to_=0)
# 0.4547273151676602
# Exploring path  path(from_=1, to_=0)
# 0.9422752696057238
# Exploring path  path(from_=0, to_=2)
# 0.6050128066303246
# Exploring path  path(from_=2, to_=5)
# 0.1786309834394687
# Exploring path  path(from_=3, to_=2)
# 0.5268815651518941
# Exploring path  path(from_=0, to_=3)
# 0.6200197184019715
# Exploring path  path(from_=3, to_=1)
# 0.8850756294611765
# Exploring path  path(from_=3, to_=4)
# 0.3445695268391007
# Exploring path  path(from_=0, to_=2)
# 0.13999715234461263
# Exploring path  path(from_=3, to_=5)
# 0.009409631265862917
# Exploiting path  path(from_=0, to_=1)
# 0.4784061957252759
# Exploring path  path(from_=3, to_=4)
# 0.8750996998113961
# Exploring path  path(from_=0, to_=5)
# 0.2035707326453282
# Exploring path  path(from_=4, to_=5)
# 0.327590563639546
# Exploring path  path(from_=4, to_=2)
# 0.7809709968432419
# Exploring path  path(from_=2, to_=3)
# 0.5980563292369406
# Exploring path  path(from_=4, to_=3)
# 0.7626757344557944
# Exploring path  path(from_=3, to_=0)
# 0.21356775293632946
# Exploring path  path(from_=4, to_=2)
# 0.36168634776344355
# Exploring path  path(from_=1, to_=2)
# 0.8947233799261134
# Exploring path  path(from_=1, to_=4)
# 0.7218400435491829
# Exploring path  path(from_=5, to_=1)
# 0.5859675069781638
# Exploring path  path(from_=1, to_=1)
# 0.8628290091886132
# Exploring path  path(from_=3, to_=4)
# 0.5108197097715662
# Exploring path  path(from_=1, to_=1)
# 0.405739618592872
# Exploring path  path(from_=0, to_=3)
# 0.36178387440281157
# Exploring path  path(from_=5, to_=1)
# 0.19816677813702155
# Exploring path  path(from_=5, to_=5)
# 0.9249531565770435
# Exploring path  path(from_=4, to_=3)
# 0.006633369557562219
# Exploiting path  path(from_=4, to_=5)
# 0.13359764156991716
# Exploring path  path(from_=5, to_=1)
# 0.21731213481314116
# Exploring path  path(from_=5, to_=4)
# 0.4564757032604131
# Exploring path  path(from_=0, to_=5)
# 0.7411615489787298
# Exploring path  path(from_=1, to_=2)
# 0.6168426486613052
# Exploring path  path(from_=3, to_=0)
# 0.35958278832941626
# Exploring path  path(from_=0, to_=0)
# 0.03567472525707294
# Exploiting path  path(from_=2, to_=3)
# 0.4725998593899712
# Exploring path  path(from_=2, to_=0)
# 0.9583266262915974
# Exploring path  path(from_=0, to_=1)
# 0.8049394777403103
# Exploring path  path(from_=1, to_=3)
# 0.06288074900900464
# Exploiting path  path(from_=5, to_=5)
# 0.8700658491533465
# Exploring path  path(from_=1, to_=4)
# 0.911841167567681
# Exploring path  path(from_=0, to_=4)
# 0.7988802812423961
# Exploring path  path(from_=5, to_=2)
# 0.5469593844586899
# Exploring path  path(from_=0, to_=4)
# 0.07779643995314611
# Exploiting path  path(from_=1, to_=2)
# 0.18633599271514734
# Exploring path  path(from_=1, to_=2)
# 0.9250883996342679
# Exploring path  path(from_=3, to_=0)
# 0.3376878906731975
# Exploring path  path(from_=5, to_=0)
# 0.9830329882232776
# Exploring path  path(from_=1, to_=4)
# 0.6350742750367423
# Exploring path  path(from_=2, to_=5)
# 0.10810460038343894
# Exploring path  path(from_=5, to_=1)
# 0.8140347221645506
# Exploring path  path(from_=1, to_=1)
# 0.3231873521132671
# Exploring path  path(from_=0, to_=2)
# 0.37300874125231454
# Exploring path  path(from_=0, to_=0)
# 0.8101777428493725
# Exploring path  path(from_=4, to_=5)
# 0.13567889743556305
# Exploring path  path(from_=4, to_=1)
# 0.7325835208827061
# Exploring path  path(from_=3, to_=1)
# 0.5531371292543582
# Exploring path  path(from_=2, to_=0)
# 0.3404636058122348
# Exploring path  path(from_=0, to_=1)
# 0.07361729339582757
# Exploiting path  path(from_=5, to_=5)
# 0.7532257813800045
# Exploring path  path(from_=4, to_=1)
# 0.49324262873234015
# Exploring path  path(from_=5, to_=3)
# 0.3580335637973864
# Exploring path  path(from_=5, to_=5)
# 0.2970636789776604
# Exploring path  path(from_=2, to_=5)
# 0.9617982710828836
# Exploring path  path(from_=1, to_=0)
# 0.8208615786581919
# Exploring path  path(from_=0, to_=1)
# 0.8901006567914259
# Exploring path  path(from_=2, to_=5)
# 0.9485197089661369
# Exploring path  path(from_=1, to_=4)
# 0.8795024821310758
# Exploring path  path(from_=5, to_=4)
# 0.08930888766133305
# Exploiting path  path(from_=1, to_=2)
# 0.571597134516111
# Exploring path  path(from_=1, to_=5)
# 0.8050464044123568
# Exploring path  path(from_=1, to_=0)
# 0.6673167454977057
# Exploring path  path(from_=1, to_=1)
# 0.6494754452763329
# Exploring path  path(from_=3, to_=0)
# 0.42919702027368245
# Exploring path  path(from_=2, to_=3)
# 0.5602502550545292
# Exploring path  path(from_=5, to_=1)
# 0.9560032346664891
# Exploring path  path(from_=4, to_=5)
# 0.1252540922507761
# Exploring path  path(from_=0, to_=3)
# 0.42106100742493247
# Exploring path  path(from_=1, to_=5)
# 0.6334809159361228
# Exploring path  path(from_=1, to_=4)
# 0.7011791684076714
# Exploring path  path(from_=4, to_=0)
# 0.5144378828558556
# Exploring path  path(from_=0, to_=4)
# 0.6189939094878856
# Exploring path  path(from_=5, to_=1)
# 0.9804201321388208
# Exploring path  path(from_=5, to_=5)
# 0.07231553299070848
# Exploiting path  path(from_=5, to_=5)
# 0.12931460516596416
# Exploring path  path(from_=2, to_=1)
# 0.6778339628526822
# Exploring path  path(from_=1, to_=5)
# 0.4559446134171069
# Exploring path  path(from_=3, to_=2)
# 0.04774572956843126
# Exploiting path  path(from_=1, to_=2)
# 0.39366862191440855
# Exploring path  path(from_=0, to_=4)
# 0.7467586831090752
# Exploring path  path(from_=0, to_=2)
# 0.5546874198361262
# Exploring path  path(from_=2, to_=2)
# 0.22666193577248572
# Exploring path  path(from_=3, to_=1)
# 0.9598144153562835
# Exploring path  path(from_=1, to_=5)
# 0.39186117165541356
# Exploring path  path(from_=1, to_=0)
# 0.3004625571063332
# Exploring path  path(from_=5, to_=3)
# 0.007397503483876133
# Exploiting path  path(from_=3, to_=4)
# 0.0014697066637543443
# Exploiting path  path(from_=3, to_=4)
# 0.8339688184324144
# Exploring path  path(from_=0, to_=1)
# 0.001808421259313131
# Exploiting path  path(from_=3, to_=4)
# 0.818583036316203
# Exploring path  path(from_=3, to_=1)
# 0.2683739949254753
# Exploring path  path(from_=1, to_=2)
# 0.5695754455984838
# Exploring path  path(from_=2, to_=4)
# 0.30897755595288756
# Exploring path  path(from_=2, to_=3)
# 0.4835658957368232
# Exploring path  path(from_=3, to_=3)
# 0.9853978856916217
# Exploring path  path(from_=2, to_=1)
# 0.8054583625529573
# Exploring path  path(from_=5, to_=2)
# 0.46081331019936467
# Exploring path  path(from_=4, to_=3)
# 0.6888126382370175
# Exploring path  path(from_=4, to_=4)
# 0.5632941648950898
# Exploring path  path(from_=0, to_=2)
# 0.8864522545193645
# Exploring path  path(from_=3, to_=3)
# 0.08978365281468237
# Exploiting path  path(from_=5, to_=5)
# 0.5410689225068379
# Exploring path  path(from_=4, to_=4)
# 0.27839557198891063
# Exploring path  path(from_=5, to_=1)
# 0.8147456430353718
# Exploring path  path(from_=2, to_=5)
# 0.9837578550804617
# Exploring path  path(from_=1, to_=3)
# 0.9717070647372428
# Exploring path  path(from_=1, to_=1)
# 0.38993406960473265
# Exploring path  path(from_=4, to_=1)
# 0.30794030289429697
# Exploring path  path(from_=0, to_=3)
# 0.753714125718269
# Exploring path  path(from_=1, to_=0)
# 0.3736046007224576
# Exploring path  path(from_=5, to_=1)
# 0.8982979490381356
# Exploring path  path(from_=1, to_=4)
# 0.4359964621215371
# Exploring path  path(from_=0, to_=0)
# 0.5464098659488321
# Exploring path  path(from_=3, to_=2)
# 0.9972394493330363
# Exploring path  path(from_=1, to_=5)
# 0.7915093244728236
# Exploring path  path(from_=3, to_=1)
# 0.9832871841222576
# Exploring path  path(from_=4, to_=1)
# 0.8959819618989815
# Exploring path  path(from_=4, to_=4)
# 0.6055400763585088
# Exploring path  path(from_=2, to_=1)
# 0.6459873290355695
# Exploring path  path(from_=0, to_=3)
# 0.9103183576272079
# Exploring path  path(from_=4, to_=0)
# 0.7830307147697086
# Exploring path  path(from_=0, to_=1)
# 0.3238800461495378
# Exploring path  path(from_=4, to_=2)
# 0.9573093496666858
# Exploring path  path(from_=5, to_=5)
# 0.4674589435412977
# Exploring path  path(from_=0, to_=1)
# 0.047661432681409543
# Exploiting path  path(from_=3, to_=4)
# 0.2576306683873384
# Exploring path  path(from_=2, to_=5)
# 0.26427986976096773
# Exploring path  path(from_=3, to_=4)
# 0.04755258351269942
# Exploiting path  path(from_=2, to_=3)
# 0.011249008908009395
# Exploiting path  path(from_=2, to_=3)
# 0.22614026206336768
# Exploring path  path(from_=5, to_=3)
# 0.6814983969987659
# Exploring path  path(from_=5, to_=1)
# 0.6943459361771798
# Exploring path  path(from_=3, to_=2)
# 0.6572225911416562
# Exploring path  path(from_=0, to_=1)
# 0.4192351020739117
# Exploring path  path(from_=0, to_=0)
# 0.5812649514751854
# Exploring path  path(from_=4, to_=0)
# 0.36611350785173224
# Exploring path  path(from_=0, to_=5)
# 0.5660203975331067
# Exploring path  path(from_=5, to_=4)
# 0.43067248121284596
# Exploring path  path(from_=3, to_=5)
# 0.6881233423182109
# Exploring path  path(from_=4, to_=2)
# 0.8398388028688382
# Exploring path  path(from_=0, to_=0)
# 0.023182866876786612
# Exploiting path  path(from_=1, to_=2)
# 0.8472789895430078
# Exploring path  path(from_=4, to_=4)
# 0.15492163619837984
# Exploring path  path(from_=0, to_=2)
# 0.11990480883490773
# Exploring path  path(from_=2, to_=5)
# 0.019822582078531936
# Exploiting path  path(from_=4, to_=5)
# 0.898909600640251
# Exploring path  path(from_=2, to_=0)
# 0.6641602956027338
# Exploring path  path(from_=3, to_=5)
# 0.6573914377939701
# Exploring path  path(from_=5, to_=3)
# 0.23644628538007206
# Exploring path  path(from_=0, to_=1)
# 0.7164581003479222
# Exploring path  path(from_=4, to_=4)
# 0.5748602172480277
# Exploring path  path(from_=0, to_=0)
# 0.5855905431710207
# Exploring path  path(from_=1, to_=0)
# 0.8189397429528745
# Exploring path  path(from_=1, to_=1)
# 0.8242941809889152
# Exploring path  path(from_=5, to_=4)
# 0.17062047835913552
# Exploring path  path(from_=0, to_=0)
# 0.20007908825044196
# Exploring path  path(from_=4, to_=1)
# 0.33016645678426537
# Exploring path  path(from_=2, to_=0)
# 0.20531213756000166
# Exploring path  path(from_=5, to_=1)
# 0.7878674489159156
# Exploring path  path(from_=4, to_=1)
# 0.3597998804739512
# Exploring path  path(from_=0, to_=5)
# 0.21005503992362118
# Exploring path  path(from_=1, to_=3)
# 0.0030451199748481317
# Exploiting path  path(from_=2, to_=3)
# 0.8189301117824552
# Exploring path  path(from_=1, to_=4)
# 0.6532807675864667
# Exploring path  path(from_=2, to_=2)
# 0.7752165268796609
# Exploring path  path(from_=4, to_=2)
# 0.04247928980836402
# Exploiting path  path(from_=5, to_=5)
# 0.9755499071593046
# Exploring path  path(from_=2, to_=3)
# 0.6575127328938756
# Exploring path  path(from_=4, to_=4)
# 0.35449541574021204
# Exploring path  path(from_=4, to_=4)
# 0.996652041340161
# Exploring path  path(from_=3, to_=3)
# 0.8128075905084795
# Exploring path  path(from_=5, to_=4)
# 0.6464298040018575
# Exploring path  path(from_=1, to_=1)
# 0.634768680723445
# Exploring path  path(from_=4, to_=0)
# 0.08114054506325508
# Exploiting path  path(from_=3, to_=4)
# 0.479809433442134
# Exploring path  path(from_=1, to_=1)
# 0.19019041567651296
# Exploring path  path(from_=3, to_=2)
# 0.652044148260324
# Exploring path  path(from_=4, to_=3)
# 0.10433523608693107
# Exploring path  path(from_=1, to_=2)
# 0.43710856987259084
# Exploring path  path(from_=2, to_=1)
# 0.25884057932347315
# Exploring path  path(from_=4, to_=2)
# 0.73013319010966
# Exploring path  path(from_=0, to_=0)
# 0.11512383972877083
# Exploring path  path(from_=0, to_=2)
# 0.7893142584134187
# Exploring path  path(from_=0, to_=4)
# 0.20631618233307603
# Exploring path  path(from_=1, to_=0)
# 0.02694889986696203
# Exploiting path  path(from_=0, to_=1)
# 0.1117915542108946
# Exploring path  path(from_=3, to_=4)
# 0.4240520866716704
# Exploring path  path(from_=4, to_=4)
# 0.752264103881799
# Exploring path  path(from_=0, to_=5)
# 0.17292796912861652
# Exploring path  path(from_=0, to_=1)
# 0.0807564250978382
# Exploiting path  path(from_=1, to_=2)
# 0.2790958473043532
# Exploring path  path(from_=5, to_=4)
# 0.1133961139096682
# Exploring path  path(from_=2, to_=1)
# 0.3019630625623998
# Exploring path  path(from_=4, to_=5)
# 0.08641507608105514
# Exploiting path  path(from_=4, to_=5)
# 0.9684213849192667
# Exploring path  path(from_=5, to_=0)
# 0.10427513648272935
# Exploring path  path(from_=5, to_=5)
# 0.46757520748382586
# Exploring path  path(from_=3, to_=5)
# 0.0026511016588596226
# Exploiting path  path(from_=4, to_=5)
# 0.8178485013602492
# Exploring path  path(from_=1, to_=2)
# 0.07187682569278875
# Exploiting path  path(from_=5, to_=5)
# 0.27899664478516173
# Exploring path  path(from_=5, to_=0)
# 0.9605094506887135
# Exploring path  path(from_=1, to_=0)
# 0.9914612981986832
# Exploring path  path(from_=3, to_=2)
# 0.9929310539125203
# Exploring path  path(from_=3, to_=2)
# 0.6228655066067171
# Exploring path  path(from_=4, to_=2)
# 0.21902353008824849
# Exploring path  path(from_=3, to_=1)
# 0.856685843248033
# Exploring path  path(from_=1, to_=3)
# 0.4862604394019967
# Exploring path  path(from_=0, to_=5)
# 0.7147884280446849
# Exploring path  path(from_=2, to_=0)
# 0.04192357830363935
# Exploiting path  path(from_=3, to_=4)
# 0.7256906550451453
# Exploring path  path(from_=3, to_=5)
# 0.6918266629795838
# Exploring path  path(from_=5, to_=1)
# 0.4075722586609335
# Exploring path  path(from_=4, to_=5)
# 0.7815957863570674
# Exploring path  path(from_=0, to_=4)
# 0.2687430837679322
# Exploring path  path(from_=3, to_=3)
# 0.3031765203921938
# Exploring path  path(from_=2, to_=3)
# 0.7544888755438863
# Exploring path  path(from_=1, to_=1)
# 0.24321702025193137
# Exploring path  path(from_=5, to_=0)
# 0.27648099910863433
# Exploring path  path(from_=0, to_=5)
# 0.38985688150006215
# Exploring path  path(from_=1, to_=3)
# 0.7308034452197867
# Exploring path  path(from_=4, to_=5)
# 0.13600497474166406
# Exploring path  path(from_=5, to_=5)
# 0.05969640557039668
# Exploiting path  path(from_=0, to_=1)
# 0.03749819714426994
# Exploiting path  path(from_=1, to_=2)
# 0.2541582251970089
# Exploring path  path(from_=5, to_=1)
# 0.49799549578306823
# Exploring path  path(from_=1, to_=2)
# 0.08402289975699762
# Exploiting path  path(from_=5, to_=5)
# 0.9933156859277709
# Exploring path  path(from_=3, to_=4)
# 0.10280675007255125
# Exploring path  path(from_=1, to_=2)
# 0.004071031743152043
# Exploiting path  path(from_=1, to_=2)
# 0.7704248075663176
# Exploring path  path(from_=1, to_=0)
# 0.9386994154258234
# Exploring path  path(from_=1, to_=1)
# 0.4823179906717988
# Exploring path  path(from_=5, to_=4)
# 0.4908048171681213
# Exploring path  path(from_=5, to_=0)
# 0.30977113848982685
# Exploring path  path(from_=0, to_=4)
# 0.6499985601388419
# Exploring path  path(from_=4, to_=4)
# 0.8201683567796054
# Exploring path  path(from_=1, to_=0)
# 0.46118397658298327
# Exploring path  path(from_=3, to_=5)
# 0.5576732246105569
# Exploring path  path(from_=1, to_=2)
# 0.9437367405374404
# Exploring path  path(from_=4, to_=5)
# 0.8515524500934072
# Exploring path  path(from_=4, to_=4)
# 0.02753418187994039
# Exploiting path  path(from_=1, to_=2)
# 0.7831054184930186
# Exploring path  path(from_=5, to_=4)
# 0.6083222275477674
# Exploring path  path(from_=5, to_=5)
# 0.32388521713156404
# Exploring path  path(from_=3, to_=4)
# 0.5771256806598395
# Exploring path  path(from_=4, to_=1)
# 0.5692480746641707
# Exploring path  path(from_=0, to_=1)
# 0.9153129380632593
# Exploring path  path(from_=4, to_=2)
# 0.321647912668666
# Exploring path  path(from_=5, to_=1)
# 0.049173118107706526
# Exploiting path  path(from_=4, to_=5)
# 0.061426170270153846
# Exploiting path  path(from_=2, to_=3)
# 0.4858546733728566
# Exploring path  path(from_=5, to_=4)
# 0.7047860924009233
# Exploring path  path(from_=1, to_=4)
# 0.41650815358969595
# Exploring path  path(from_=5, to_=2)
# 0.5300655850450525
# Exploring path  path(from_=1, to_=1)
# 0.2623672324616466
# Exploring path  path(from_=0, to_=2)
# 0.4976781734899449
# Exploring path  path(from_=2, to_=5)
# 0.4654049331576563
# Exploring path  path(from_=2, to_=1)
# 0.5504870340498084
# Exploring path  path(from_=2, to_=4)
# 0.7494112223475676
# Exploring path  path(from_=0, to_=5)
# 0.9200643606526125
# Exploring path  path(from_=4, to_=3)
# 0.42094050059201504
# Exploring path  path(from_=3, to_=3)
# 0.2811035693993099
# Exploring path  path(from_=4, to_=0)
# 0.028036557267502316
# Exploiting path  path(from_=2, to_=3)
# 0.6089582342305478
# Exploring path  path(from_=1, to_=2)
# 0.21589292547287986
# Exploring path  path(from_=1, to_=0)
# 0.35398679446049963
# Exploring path  path(from_=4, to_=2)
# 0.11105165886335167
# Exploring path  path(from_=0, to_=5)
# 0.29919982091062736
# Exploring path  path(from_=5, to_=5)
# 0.25630308138482927
# Exploring path  path(from_=1, to_=3)
# 0.550379096418897
# Exploring path  path(from_=4, to_=4)
# 0.2940155458909093
# Exploring path  path(from_=2, to_=2)
# 0.7646214558780294
# Exploring path  path(from_=4, to_=4)
# 0.43229971686050983
# Exploring path  path(from_=3, to_=3)
# 0.39509296476849587
# Exploring path  path(from_=0, to_=4)
# 0.10648802906873156
# Exploring path  path(from_=1, to_=3)
# 0.7660171082057015
# Exploring path  path(from_=3, to_=5)
# 0.08075728822303596
# Exploiting path  path(from_=4, to_=5)
# 0.4016900468758009
# Exploring path  path(from_=3, to_=4)
# 0.9186297276332219
# Exploring path  path(from_=2, to_=3)
# 0.5472922511208546
# Exploring path  path(from_=0, to_=4)
# 0.6309954778926672
# Exploring path  path(from_=2, to_=5)
# 0.6061596708629312
# Exploring path  path(from_=1, to_=0)
# 0.17250220353265466
# Exploring path  path(from_=0, to_=5)
# 0.7136329786942385
# Exploring path  path(from_=2, to_=2)
# 0.6576761113407079
# Exploring path  path(from_=0, to_=2)
# 0.7030424047097497
# Exploring path  path(from_=3, to_=5)
# 0.8085794114042175
# Exploring path  path(from_=3, to_=2)
# 0.3755020528476283
# Exploring path  path(from_=4, to_=2)
# 0.2648014812325824
# Exploring path  path(from_=0, to_=2)
# 0.1989642010774597
# Exploring path  path(from_=0, to_=1)
# 0.3260045259055012
# Exploring path  path(from_=1, to_=2)
# 0.19050542084375777
# Exploring path  path(from_=4, to_=5)
# 0.3367210022226743
# Exploring path  path(from_=5, to_=3)
# 0.12636068479587725
# Exploring path  path(from_=4, to_=0)
# 0.24853176185319137
# Exploring path  path(from_=0, to_=5)
# 0.37963735543241817
# Exploring path  path(from_=0, to_=1)
# 0.20100377487682153
# Exploring path  path(from_=2, to_=3)
# 0.6729392473496257
# Exploring path  path(from_=0, to_=3)
# 0.3406862174750175
# Exploring path  path(from_=3, to_=1)
# 0.9476259808497873
# Exploring path  path(from_=3, to_=5)
# 0.639928272488462
# Exploring path  path(from_=4, to_=3)
# 0.4790090971165619
# Exploring path  path(from_=3, to_=2)
# 0.9147451387816908
# Exploring path  path(from_=4, to_=3)
# 0.23708297781668408
# Exploring path  path(from_=3, to_=3)
# 0.27297004467789576
# Exploring path  path(from_=5, to_=5)
# 0.8633508228534623
# Exploring path  path(from_=3, to_=3)
# 0.26491842813483646
# Exploring path  path(from_=0, to_=2)
# 0.3152345435138071
# Exploring path  path(from_=2, to_=4)
# 0.4174207750720711
# Exploring path  path(from_=5, to_=0)
# 0.8380557535972765
# Exploring path  path(from_=0, to_=1)
# 0.286688154982944
# Exploring path  path(from_=2, to_=4)
# 0.6552057802351497
# Exploring path  path(from_=1, to_=5)
# 0.10277475044720774
# Exploring path  path(from_=0, to_=2)
# 0.4530320341705327
# Exploring path  path(from_=4, to_=4)
# 0.8542478098651627
# Exploring path  path(from_=1, to_=1)
# 0.301670599913899
# Exploring path  path(from_=0, to_=3)
# 0.4533879282502188
# Exploring path  path(from_=3, to_=5)
# 0.33917628438367975
# Exploring path  path(from_=4, to_=1)
# 0.44511280975139567
# Exploring path  path(from_=3, to_=3)
# 0.3985133110208686
# Exploring path  path(from_=4, to_=1)
# 0.32164562881061853
# Exploring path  path(from_=4, to_=3)
# 0.4441991607321749
# Exploring path  path(from_=2, to_=2)
# 0.6414119036427183
# Exploring path  path(from_=2, to_=5)
# 0.6657101663348235
# Exploring path  path(from_=5, to_=1)
# 0.6949308724382305
# Exploring path  path(from_=2, to_=5)
# 0.900513193411519
# Exploring path  path(from_=4, to_=4)
# 0.5833757413886987
# Exploring path  path(from_=1, to_=3)
# 0.5414083690803404
# Exploring path  path(from_=2, to_=2)
# 0.13948840481142166
# Exploring path  path(from_=5, to_=5)
# 0.5799894228726344
# Exploring path  path(from_=2, to_=1)
# 0.5771636744955078
# Exploring path  path(from_=5, to_=0)
# 0.5337301022903663
# Exploring path  path(from_=5, to_=5)
# 0.007439821009581404
# Exploiting path  path(from_=3, to_=4)
# 0.2002152874577514
# Exploring path  path(from_=4, to_=0)
# 0.5530760634478732
# Exploring path  path(from_=0, to_=2)
# 0.39538708463151184
# Exploring path  path(from_=1, to_=4)
# 0.7557365693157224
# Exploring path  path(from_=4, to_=3)
# 0.1553373082159646
# Exploring path  path(from_=2, to_=5)
# 0.685205165471304
# Exploring path  path(from_=0, to_=4)
# 0.9178862557515934
# Exploring path  path(from_=3, to_=0)
# 0.7861553634707341
# Exploring path  path(from_=3, to_=1)
# 0.24628516042060056
# Exploring path  path(from_=1, to_=0)
# 0.21116724120332153
# Exploring path  path(from_=3, to_=1)
# 0.3050289604914417
# Exploring path  path(from_=0, to_=0)
# 0.43401079696693745
# Exploring path  path(from_=2, to_=5)
# 0.20089465160412012
# Exploring path  path(from_=0, to_=3)
# 0.42110264723747093
# Exploring path  path(from_=1, to_=5)
# 0.816423002489117
# Exploring path  path(from_=1, to_=5)
# 0.21725222522363363
# Exploring path  path(from_=5, to_=1)
# 0.08116498862351462
# Exploiting path  path(from_=4, to_=5)
# 0.19391179990774876
# Exploring path  path(from_=5, to_=2)
# 0.4761698868739942
# Exploring path  path(from_=5, to_=2)
# 0.446799857574544
# Exploring path  path(from_=1, to_=5)
# 0.27647795188346314
# Exploring path  path(from_=4, to_=4)
# 0.026932057182627367
# Exploiting path  path(from_=0, to_=1)
# 0.14723004645586202
# Exploring path  path(from_=4, to_=4)
# 0.23517441621763036
# Exploring path  path(from_=1, to_=1)
# 0.7654709846483679
# Exploring path  path(from_=1, to_=5)
# 0.2883476029192681
# Exploring path  path(from_=3, to_=5)
# 0.6604003459494056
# Exploring path  path(from_=2, to_=3)
# 0.6599637540280162
# Exploring path  path(from_=4, to_=3)
# 0.9592942469478162
# Exploring path  path(from_=1, to_=2)
# 0.9632322831706882
# Exploring path  path(from_=4, to_=0)
# 0.9407151306419743
# Exploring path  path(from_=1, to_=5)
# 0.40501178498484347
# Exploring path  path(from_=5, to_=2)
# 0.7024949595917617
# Exploring path  path(from_=0, to_=3)
# 0.9775051233258955
# Exploring path  path(from_=3, to_=5)
# 0.08643431587730754
# Exploiting path  path(from_=0, to_=1)
# 0.4745628140624323
# Exploring path  path(from_=3, to_=0)
# 0.6630404380936541
# Exploring path  path(from_=5, to_=1)
# 0.35142273004016067
# Exploring path  path(from_=5, to_=2)
# 0.6123332256140721
# Exploring path  path(from_=5, to_=4)
# 0.5935997416234019
# Exploring path  path(from_=2, to_=5)
# 0.5550487597158855
# Exploring path  path(from_=5, to_=4)
# 0.42110559866395125
# Exploring path  path(from_=3, to_=5)
# 0.9143605589621567
# Exploring path  path(from_=1, to_=4)
# 0.14808463447442255
# Exploring path  path(from_=4, to_=5)
# 0.6370122373922712
# Exploring path  path(from_=1, to_=0)
# 0.04874805673520921
# Exploiting path  path(from_=0, to_=1)
# 0.40107116509287444
# Exploring path  path(from_=0, to_=3)
# 0.3134513003919599
# Exploring path  path(from_=1, to_=1)
# 0.02378270331021093
# Exploiting path  path(from_=0, to_=1)
# 0.6017067294465955
# Exploring path  path(from_=3, to_=1)
# 0.2991667670952889
# Exploring path  path(from_=4, to_=1)
# 0.11209438880819089
# Exploring path  path(from_=0, to_=1)
# 0.7030098080287492
# Exploring path  path(from_=1, to_=0)
# 0.039793221521312705
# Exploiting path  path(from_=2, to_=3)
# 0.33609044583152115
# Exploring path  path(from_=1, to_=4)
# 0.9005856123444043
# Exploring path  path(from_=5, to_=5)
# 0.1490039105257387
# Exploring path  path(from_=4, to_=0)
# 0.7151353082435018
# Exploring path  path(from_=4, to_=1)
# 0.5491462889130491
# Exploring path  path(from_=1, to_=5)
# 0.8588264561289217
# Exploring path  path(from_=1, to_=3)
# 0.5337336995254222
# Exploring path  path(from_=0, to_=3)
# 0.7019297516940465
# Exploring path  path(from_=2, to_=4)
# 0.18257826432482027
# Exploring path  path(from_=0, to_=4)
# 0.08120186143252295
# Exploiting path  path(from_=1, to_=2)
# 0.4793572931096437
# Exploring path  path(from_=0, to_=4)
# 0.7572822230533808
# Exploring path  path(from_=0, to_=0)
# 0.3829900721655003
# Exploring path  path(from_=1, to_=4)
# 0.470693462367089
# Exploring path  path(from_=5, to_=1)
# 0.7958866959130636
# Exploring path  path(from_=3, to_=4)
# 0.5140980074911992
# Exploring path  path(from_=5, to_=1)
# 0.025533180525917354
# Exploiting path  path(from_=1, to_=2)
# 0.7848608340725519
# Exploring path  path(from_=3, to_=2)
# 0.43752413598879025
# Exploring path  path(from_=4, to_=3)
# 0.13248144549338492
# Exploring path  path(from_=2, to_=4)
# 0.5820997873072654
# Exploring path  path(from_=2, to_=3)
# 0.8815407310917353
# Exploring path  path(from_=2, to_=0)
# 0.8502243519836925
# Exploring path  path(from_=0, to_=3)
# 0.12005901574878619
# Exploring path  path(from_=5, to_=0)
# 0.7806487383108434
# Exploring path  path(from_=2, to_=1)
# 0.9206905152706931
# Exploring path  path(from_=4, to_=2)
# 0.6278574902036866
# Exploring path  path(from_=5, to_=2)
# 0.7974724631088785
# Exploring path  path(from_=5, to_=0)
# 0.6147347772303914
# Exploring path  path(from_=2, to_=0)
# 0.5629368930581623
# Exploring path  path(from_=1, to_=1)
# 0.8832399985077836
# Exploring path  path(from_=0, to_=2)
# 0.16014859612683774
# Exploring path  path(from_=4, to_=0)
# 0.3499922514956042
# Exploring path  path(from_=3, to_=0)
# 0.4952800471475476
# Exploring path  path(from_=2, to_=3)
# 0.7591620749516649
# Exploring path  path(from_=1, to_=4)
# 0.7593734922456545
# Exploring path  path(from_=0, to_=1)
# 0.7216876764053194
# Exploring path  path(from_=3, to_=5)
# 0.18556913410007503
# Exploring path  path(from_=2, to_=4)
# 0.3435459515479077
# Exploring path  path(from_=3, to_=2)
# 0.9196621991378205
# Exploring path  path(from_=2, to_=1)
# 0.07252243417096338
# Exploiting path  path(from_=0, to_=1)
# 0.47662643752006517
# Exploring path  path(from_=4, to_=0)
# 0.12945776165264067
# Exploring path  path(from_=5, to_=2)
# 0.28911712586781013
# Exploring path  path(from_=2, to_=3)
# 0.008901895170659535
# Exploiting path  path(from_=4, to_=5)
# 0.5841066016500571
# Exploring path  path(from_=5, to_=2)
# 0.5453612699402683
# Exploring path  path(from_=5, to_=1)
# 0.25257065828026826
# Exploring path  path(from_=2, to_=2)
# 0.6636441184328637
# Exploring path  path(from_=1, to_=0)
# 0.1261634856594186
# Exploring path  path(from_=3, to_=3)
# 0.1228103859769204
# Exploring path  path(from_=5, to_=4)
# 0.8102930810331653
# Exploring path  path(from_=5, to_=3)
# 0.9560535696652429
# Exploring path  path(from_=2, to_=2)
# 0.49503570822028
# Exploring path  path(from_=2, to_=2)
# 0.28152704289841124
# Exploring path  path(from_=3, to_=0)
# 0.8194529476492183
# Exploring path  path(from_=5, to_=5)
# 0.13878981904814858
# Exploring path  path(from_=3, to_=5)
# 0.9343416199801808
# Exploring path  path(from_=0, to_=4)
# 0.9425627330156123
# Exploring path  path(from_=2, to_=3)
# 0.6269943523439049
# Exploring path  path(from_=0, to_=5)
# 0.8910704786870526
# Exploring path  path(from_=0, to_=1)
# 0.1273414228140609
# Exploring path  path(from_=0, to_=5)
# 0.849086068700762
# Exploring path  path(from_=3, to_=1)
# 0.5472443009379724
# Exploring path  path(from_=5, to_=5)
# 0.9659988197989559
# Exploring path  path(from_=5, to_=5)
# 0.24374617366665907
# Exploring path  path(from_=5, to_=4)
# 0.7678435598503625
# Exploring path  path(from_=5, to_=5)
# 0.5923600927353113
# Exploring path  path(from_=2, to_=1)
# 0.5322890196000578
# Exploring path  path(from_=1, to_=3)
# 0.8417505986317962
# Exploring path  path(from_=1, to_=2)
# 0.9506976211788782
# Exploring path  path(from_=3, to_=0)
# 0.4902269322513595
# Exploring path  path(from_=1, to_=1)
# 0.2723057090904374
# Exploring path  path(from_=2, to_=0)
# 0.5645661230619333
# Exploring path  path(from_=0, to_=4)
# 0.37979638904220436
# Exploring path  path(from_=2, to_=4)
# 0.6311986585485104
# Exploring path  path(from_=5, to_=0)
# 0.6156966363928039
# Exploring path  path(from_=2, to_=2)
# 0.25322403769472446
# Exploring path  path(from_=1, to_=0)
# 0.4046540261563333
# Exploring path  path(from_=2, to_=4)
# 0.2384746108064827
# Exploring path  path(from_=4, to_=0)
# 0.4532307089644635
# Exploring path  path(from_=5, to_=5)
# 0.8175909738970525
# Exploring path  path(from_=4, to_=3)
# 0.15800673098860196
# Exploring path  path(from_=2, to_=2)
# 0.29595477651582713
# Exploring path  path(from_=4, to_=4)
# 0.2696941729916664
# Exploring path  path(from_=2, to_=5)
# 0.8398853284179434
# Exploring path  path(from_=4, to_=3)
# 0.051083894618680126
# Exploiting path  path(from_=2, to_=3)
# 0.9976085001059675
# Exploring path  path(from_=5, to_=4)
# 0.5572367565325428
# Exploring path  path(from_=5, to_=4)
# 0.6590748590900897
# Exploring path  path(from_=2, to_=0)
# 0.136972533943039
# Exploring path  path(from_=5, to_=4)
# 0.36558168053518714
# Exploring path  path(from_=3, to_=3)
# 0.7561868773018751
# Exploring path  path(from_=0, to_=2)
# 0.8737641384155551
# Exploring path  path(from_=5, to_=2)
# 0.6748997162202492
# Exploring path  path(from_=0, to_=4)
# 0.966542988140349
# Exploring path  path(from_=5, to_=2)
# 0.10495086664328157
# Exploring path  path(from_=2, to_=4)
# 0.8715689993463961
# Exploring path  path(from_=4, to_=5)
# 0.10426082388553626
# Exploring path  path(from_=4, to_=4)
# 0.7260533868241343
# Exploring path  path(from_=3, to_=5)
# 0.9529350477857803
# Exploring path  path(from_=5, to_=0)
# 0.41610695143515064
# Exploring path  path(from_=4, to_=1)
# 0.2012217787340772
# Exploring path  path(from_=2, to_=3)
# 0.2852135277486917
# Exploring path  path(from_=4, to_=3)
# 0.964757013116477
# Exploring path  path(from_=2, to_=3)
# 0.008509118569389185
# Exploiting path  path(from_=2, to_=3)
# 0.6250097428080147
# Exploring path  path(from_=4, to_=3)
# 0.4804617072801636
# Exploring path  path(from_=1, to_=1)
# 0.9039619979433111
# Exploring path  path(from_=5, to_=3)
# 0.9524675744035644
# Exploring path  path(from_=5, to_=4)
# 0.7238389970625078
# Exploring path  path(from_=4, to_=1)
# 0.8812504886960189
# Exploring path  path(from_=0, to_=4)
# 0.3968151627423139
# Exploring path  path(from_=1, to_=3)
# 0.5917660957607636
# Exploring path  path(from_=1, to_=5)
# 0.9115553149854214
# Exploring path  path(from_=3, to_=0)
# 0.4160089092831255
# Exploring path  path(from_=3, to_=2)
# 0.30126728196493413
# Exploring path  path(from_=0, to_=1)
# 0.8264137040148206
# Exploring path  path(from_=4, to_=2)
# 0.8008353413147374
# Exploring path  path(from_=2, to_=5)
# 0.9112294638901725
# Exploring path  path(from_=0, to_=0)
# 0.8372389816221828
# Exploring path  path(from_=2, to_=2)
# 0.7111280104676252
# Exploring path  path(from_=5, to_=3)
# 0.9306337443245218
# Exploring path  path(from_=5, to_=3)
# 0.1484634932743848
# Exploring path  path(from_=1, to_=4)
# 0.6442387441407009
# Exploring path  path(from_=0, to_=3)
# 0.4475438435155944
# Exploring path  path(from_=4, to_=1)
# 0.4327355836295065
# Exploring path  path(from_=1, to_=3)
# 0.5525338505390873
# Exploring path  path(from_=4, to_=0)
# 0.43403291926974374
# Exploring path  path(from_=0, to_=3)
# 0.27047627816128506
# Exploring path  path(from_=2, to_=1)
# 0.5346474851308887
# Exploring path  path(from_=5, to_=3)
# 0.6534599521998766
# Exploring path  path(from_=0, to_=5)
# 0.014159975722538909
# Exploiting path  path(from_=1, to_=2)
# 0.45092098479477294
# Exploring path  path(from_=5, to_=3)
# 0.18456710627119766
# Exploring path  path(from_=4, to_=4)
# 0.6797366818221511
# Exploring path  path(from_=4, to_=5)
# 0.4157561104467975
# Exploring path  path(from_=2, to_=3)
# 0.5626869379651638
# Exploring path  path(from_=4, to_=2)
# 0.9913583228652147
# Exploring path  path(from_=0, to_=1)
# 0.473873487718945
# Exploring path  path(from_=0, to_=4)
# 0.13638151127134346
# Exploring path  path(from_=0, to_=4)
# 0.4743696573289552
# Exploring path  path(from_=3, to_=3)
# 0.1708787137184703
# Exploring path  path(from_=2, to_=1)
# 0.39215634325067406
# Exploring path  path(from_=2, to_=0)
# 0.8180291460192052
# Exploring path  path(from_=3, to_=1)
# 0.5138336670381497
# Exploring path  path(from_=3, to_=4)
# 0.48662236728833685
# Exploring path  path(from_=1, to_=4)
# 0.7028662513475398
# Exploring path  path(from_=1, to_=4)
# 0.37143566152597607
# Exploring path  path(from_=0, to_=0)
# 0.12850129363170681
# Exploring path  path(from_=0, to_=4)
# 0.463605987028735
# Exploring path  path(from_=1, to_=3)
# 0.8736160331529879
# Exploring path  path(from_=0, to_=4)
# 0.00010494504725122589
# Exploiting path  path(from_=2, to_=3)
# 0.3080703969006485
# Exploring path  path(from_=4, to_=2)
# 0.2050758838277008
# Exploring path  path(from_=4, to_=2)
# 0.1850669751821118
# Exploring path  path(from_=3, to_=1)
# 0.3904718959692143
# Exploring path  path(from_=5, to_=2)
# 0.7088710651935828
# Exploring path  path(from_=4, to_=4)
# 0.974794163804313
# Exploring path  path(from_=5, to_=4)
# 0.8633466685637977
# Exploring path  path(from_=0, to_=0)
# 0.304849784188273
# Exploring path  path(from_=2, to_=2)
# 0.9680872668485294
# Exploring path  path(from_=5, to_=5)
# 0.7743527866821042
# Exploring path  path(from_=2, to_=2)
# 0.9071100102866227
# Exploring path  path(from_=1, to_=4)
# 0.1662550888469041
# Exploring path  path(from_=3, to_=3)
# 0.36797127960952125
# Exploring path  path(from_=5, to_=3)
# 0.13806184175694658
# Exploring path  path(from_=3, to_=2)
# 0.6463576545948294
# Exploring path  path(from_=5, to_=4)
# 0.027409860498688987
# Exploiting path  path(from_=3, to_=4)
# 0.28410295817196796
# Exploring path  path(from_=5, to_=0)
# 0.0008879577414867557
# Exploiting path  path(from_=5, to_=5)
# 0.6071449751291533
# Exploring path  path(from_=0, to_=0)
# 0.020704956375643513
# Exploiting path  path(from_=0, to_=1)
# 0.1874031089873357
# Exploring path  path(from_=5, to_=0)
# 0.5599606212710491
# Exploring path  path(from_=2, to_=0)
# 0.4732223874388266
# Exploring path  path(from_=0, to_=5)
# 0.22528206437217624
# Exploring path  path(from_=5, to_=3)
# 0.9308703562301271
# Exploring path  path(from_=5, to_=1)
# 0.4123502005345825
# Exploring path  path(from_=4, to_=1)
# 0.34710864153633725
# Exploring path  path(from_=5, to_=2)
# 0.40288791056087436
# Exploring path  path(from_=3, to_=3)
# 0.18473362769847157
# Exploring path  path(from_=1, to_=3)
# 0.9708204513782978
# Exploring path  path(from_=3, to_=1)
# 0.9862867946038171
# Exploring path  path(from_=3, to_=3)
# 0.20629969096737244
# Exploring path  path(from_=1, to_=0)
# 0.413108285410986
# Exploring path  path(from_=4, to_=0)
# 0.09466987090965895
# Exploiting path  path(from_=0, to_=1)
# 0.4886261610971516
# Exploring path  path(from_=1, to_=5)
# 0.14718548890434413
# Exploring path  path(from_=1, to_=2)
# 0.05935801078264713
# Exploiting path  path(from_=5, to_=5)
# 0.5393763031052391
# Exploring path  path(from_=0, to_=2)
# 0.1984519499034635
# Exploring path  path(from_=1, to_=2)
# 0.8945272194251077
# Exploring path  path(from_=1, to_=2)
# 0.5971867034259905
# Exploring path  path(from_=3, to_=4)
# 0.6769481388808538
# Exploring path  path(from_=3, to_=5)
# 0.7451158550362097
# Exploring path  path(from_=3, to_=0)
# 0.21873606285202563
# Exploring path  path(from_=0, to_=3)
# 0.3367888627479484
# Exploring path  path(from_=0, to_=1)
# 0.5951417061076217
# Exploring path  path(from_=0, to_=2)
# 0.7703030502221301
# Exploring path  path(from_=3, to_=1)
# 0.5224656023928267
# Exploring path  path(from_=4, to_=4)
# 0.7650074506969227
# Exploring path  path(from_=3, to_=1)
# 0.15072255972665838
# Exploring path  path(from_=2, to_=2)
# 0.5929773455771328
# Exploring path  path(from_=3, to_=1)
# 0.7078974416815141
# Exploring path  path(from_=0, to_=3)
# 0.24705609108858362
# Exploring path  path(from_=4, to_=3)
# 0.1804448008912889
# Exploring path  path(from_=2, to_=3)
# 0.9944163152347427
# Exploring path  path(from_=5, to_=5)
# 0.9993382697933958
# Exploring path  path(from_=2, to_=2)
# 0.4885319295248848
# Exploring path  path(from_=5, to_=2)
# 0.4278152606366151
# Exploring path  path(from_=0, to_=2)
# 0.6812318863618267
# Exploring path  path(from_=2, to_=5)
# 0.2570397426935812
# Exploring path  path(from_=5, to_=4)
# 0.05002034401149136
# Exploiting path  path(from_=3, to_=4)
# {path(from_=0, to_=0): 1.9923565707481992, path(from_=2, to_=5): 2.647759910008082, path(from_=5, to_=2): 3.2960395006458376, path(from_=4, to_=0): 2.8255349972537354, path(from_=4, to_=3): 2.2822161802452423, path(from_=5, to_=5): 4.146889068877629, path(from_=4, to_=4): 2.610262296339854, path(from_=3, to_=0): 1.8742819557916388, path(from_=0, to_=2): 2.3041714298784193, path(from_=3, to_=4): 3.5191012726213535, path(from_=1, to_=1): 1.9796425232949306, path(from_=2, to_=4): 2.1678702016305302, path(from_=5, to_=3): 3.149231509243434, path(from_=3, to_=2): 1.9091752485226063, path(from_=1, to_=3): 2.170912762973693, path(from_=4, to_=2): 2.1457537286885513, path(from_=1, to_=5): 2.5252603999937975, path(from_=1, to_=4): 2.516761907225091, path(from_=2, to_=3): 3.593860910649322, path(from_=4, to_=5): 3.6356551793001306, path(from_=1, to_=0): 2.095480626072392, path(from_=0, to_=1): 3.5303404725477265, path(from_=2, to_=1): 1.855934087804855, path(from_=0, to_=5): 2.464739730290788, path(from_=0, to_=4): 2.70600903648406, path(from_=5, to_=0): 3.0124419447255097, path(from_=2, to_=0): 1.8855835769701361, path(from_=5, to_=1): 3.016782972292292, path(from_=3, to_=1): 2.291721049453984, path(from_=3, to_=5): 2.7627595870945485, path(from_=5, to_=4): 3.6385582976276476, path(from_=0, to_=3): 2.268050051295607, path(from_=4, to_=1): 1.9903467170965068, path(from_=3, to_=3): 2.2725018589092096, path(from_=1, to_=2): 3.490208286270091, path(from_=2, to_=2): 2.4666520873666498}
# {0: [1.9923565707481992, 3.5303404725477265, 2.3041714298784193, 2.268050051295607, 2.70600903648406, 2.464739730290788]}
# {1: [2.095480626072392, 1.9796425232949306, 3.490208286270091, 2.170912762973693, 2.516761907225091, 2.5252603999937975]}
# {2: [1.8855835769701361, 1.855934087804855, 2.4666520873666498, 3.593860910649322, 2.1678702016305302, 2.647759910008082]}
# {3: [1.8742819557916388, 2.291721049453984, 1.9091752485226063, 2.2725018589092096, 3.5191012726213535, 2.7627595870945485]}
# {4: [2.8255349972537354, 1.9903467170965068, 2.1457537286885513, 2.2822161802452423, 2.610262296339854, 3.6356551793001306]}
# {5: [3.0124419447255097, 3.016782972292292, 3.2960395006458376, 3.149231509243434, 3.6385582976276476, 4.146889068877629]}
# from  0
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
# from  1
# 1 2
# 2 3
# 3 4
# 4 5
# from  2
# 2 3
# 3 4
# 4 5
# from  3
# 3 4
# 4 5
# from  4
# 4 5
# from  5
# 5 5
