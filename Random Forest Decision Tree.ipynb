# %% [markdown]
# Random Forest Decision Tree model in python using **sklearn.ensemble.RandomForestClassifier()** and **sklearn.ensemble.RandomForestRegressor()**
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
import numpy as np
import pandas as pd

# %% [markdown]
# Declares the data frame variable

# %%
df = pd.DataFrame(data=[[2.50, 2.05, 0],[1.2,5.92,1],[2.5,4.92,1], [4.00,4.92,0],[3.52,1.48,0], [2.86,4.21,1]], columns=['x1', 'x2', 'Target'])
# df2 = pd.DataFrame(data=[[70,39,1,1], [17,1,7,1], [44,30, 10, 1], [69,26,2,1], [43,9,9,1], [66,27,6,1], [74,27,1,1], [118,28,114,0], [120,59,112,0], [115,44,112,0], [128,26,104,0], [54,44,114,0], [68,60,105,0], [133,54,106,0]], columns=['x0', 'x1', 'x2', 'Target'])

# %% [markdown]
# Fits the data to a Random Forest Classification model

# %%
rf = RandomForestClassifier() # RandomForestClassifier(n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)
rf.fit(df.drop('Target', 1), df.Target)
# Out:
# <ipython-input-10-66fd930a447d>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   rf.fit(df.drop('Target', 1), df.Target)
# RandomForestClassifier()

# %% [markdown]
# Makes a prediction on the value of the test variable using the Random Forest Classification model

# %%
test = np.array([1.3, 6.0]).reshape(1, -1)
print(f'Prediction made for data {test}: {rf.predict(test)}')
print(rf.decision_path(test))
# Out:
# Prediction made for data [[1.3 6. ]]: [1]
# (<1x478 sparse matrix of type '<class 'numpy.int64'>'
# 	with 257 stored elements in Compressed Sparse Row format>, array([  0,   5,   8,  13,  20,  27,  32,  39,  42,  45,  52,  59,  62,
#         67,  70,  79,  82,  87,  96, 101, 108, 115, 118, 121, 126, 129,
#        134, 137, 140, 143, 148, 153, 160, 163, 168, 173, 180, 187, 190,
#        197, 200, 205, 208, 215, 218, 221, 228, 231, 236, 241, 244, 247,
#        252, 257, 262, 265, 268, 271, 274, 277, 284, 289, 298, 301, 306,
#        311, 318, 325, 332, 339, 346, 353, 358, 361, 364, 367, 372, 379,
#        382, 389, 394, 399, 402, 405, 408, 413, 418, 421, 426, 429, 432,
#        437, 442, 449, 454, 459, 462, 467, 472, 477, 478]))
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
print(rf.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# Below is an example of a Random Forest Regression model

# %%
df2 = pd.DataFrame(data=[[1,3.2,16.9],[1,2.9,15.6],[1,1.9,11.2],[1,3.5,14.5],[1,1.1,12.2],[1,2.3,13.7]], columns=['x0', 'x1', 'Target'])

# %%
model2 = RandomForestRegressor()
model2.fit(df2.drop('Target', 1), df2.Target)
# Out:
# <ipython-input-23-b24c29551482>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   model2.fit(df2.drop('Target', 1), df2.Target)
# RandomForestRegressor()

# %%
test2 = np.array([1, 1.5]).reshape(1, -1)
print(f'Prediction made for data {test2}: {model2.predict(test2)}')
print(model2.decision_path(test2))
# Out:
# Prediction made for data [[1.  1.5]]: [12.088]
# (<1x704 sparse matrix of type '<class 'numpy.int64'>'
# 	with 269 stored elements in Compressed Sparse Row format>, array([  0,   5,  10,  19,  26,  37,  42,  51,  58,  67,  76,  83,  92,
#         99, 106, 115, 122, 127, 134, 141, 150, 155, 162, 169, 176, 181,
#        188, 197, 204, 213, 220, 227, 234, 239, 248, 251, 260, 265, 272,
#        277, 284, 291, 300, 307, 314, 319, 326, 333, 342, 349, 354, 361,
#        368, 375, 382, 389, 394, 401, 408, 415, 422, 427, 432, 439, 446,
#        453, 460, 467, 474, 485, 492, 499, 504, 509, 514, 521, 530, 537,
#        544, 551, 556, 563, 570, 577, 584, 591, 598, 607, 612, 619, 628,
#        633, 644, 653, 662, 671, 678, 687, 694, 699, 704]))
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ...

# %%
print(model2.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
